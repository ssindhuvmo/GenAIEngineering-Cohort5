# %%
import json
from typing import List, Dict, Any
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import lancedb
import openai
import groq
from dotenv import load_dotenv
import re
from google import genai
from google.genai import types

# %%
# Inputs
LANCE_DB_NAME = 'Vector_DB'
LANCEDB_TABLE_NAME = 'tech_ref'
TOP_K_PER_QUERY = 5
MAX_COMBINED_RESULTS = 20

# %%
# Initialise an client object with API key
load_dotenv ()
Retrieval_Client = groq.Groq ()
Gen_Client = genai.Client()

# Embedding Models
Embedder_1 = SentenceTransformer ("sentence-transformers/all-MiniLM-L6-v2")
Embedder_2 = SentenceTransformer ("sentence-transformers/all-mpnet-base-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# MPNetModel LOAD REPORT from: sentence-transformers/all-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %% [markdown]
# #### Utlities

# %% [markdown]
# **Query Keywords**
# > Function to identify key words from the query
# > This might help to retireve information based on the key word from the knowledge repo
# > By this it enhances the envelop of search in repo

# %%
# Identify Keywords from Query

def query_keywords (query: str, n_keywords: int = 3) -> List[str]:
    prompt = (
        'You are given a user query. With that, produce:\n'        
        f'{n_keywords} Individual Keywords that capture the crux of the query ("keywords").\n'
        'If there are fewer keywords than needed, Provide **ONLY** what is present. Dont Cookup'
        'Return JSON with keys: "keywords" (list of strings).\n'
        'User query: ' + query
    )

    messages=[
    {
        "role": "user",
        "content": prompt,
    }
    ]
    completion = Retrieval_Client.chat.completions.create(
        messages=messages,    
        model="llama-3.3-70b-versatile",
        # model="openai/gpt-oss-120b",
        stop=None,
    )

    # print (completion.choices[0].message.content)

    clean_str = re.sub(r"^```(?:json)?\s*|\s*```$", "", completion.choices[0].message.content)
    data = json.loads (clean_str)
    texts = data["keywords"]

    return texts

# %% [markdown]
# **Re Ranker**
# > Function to re-rank the set of texts based on semantic similarity with the query string
# > since Key word search might result in jus text matched content, re-ranking is needed

# %%
def re_rank_text(query: str, ref_strings: List[str]) -> List[str]:
    """
    Re-rank reference strings based on cosine similarity to a query string.

    Args:
        query: The query text.
        ref_strings: A list of reference texts to be re-ranked.

    Returns:
        List[str]: The reference strings sorted by similarity (most similar first).
    """
    _model = Embedder_1

    if not ref_strings:
        return []

    # Encode query and references
    query_emb = _model.encode(query, normalize_embeddings=True)
    ref_embs = _model.encode(ref_strings, normalize_embeddings=True)

    # Compute cosine similarity
    similarities = util.cos_sim(query_emb, ref_embs)[0]  

    # Sort reference strings by similarity (descending)
    ranked_indices = similarities.argsort(descending=True)
    ranked_refs = [ref_strings[i] for i in ranked_indices]

    return ranked_refs

# %% [markdown]
# **DB Connect**

# %%
# Connect to existing Vector DB and use data
# Create a Lance DB Vector Base
DB = lancedb.connect ('Vector_DB')

# Create a Table and add the Chunks data
table = DB.open_table ("tech_ref")
print (table.schema)
# Out:
# source: string
# topic: string
# text: string
# vector: fixed_size_list<item: float>[768]
#   child 0, item: float

# %% [markdown]
# **Text Indexing**
# Make Indexing based on the text field. This allows to run key word or text search in the DB

# %%
table.create_fts_index("text", replace=True)
print (table.schema)
# Out:
# source: string
# topic: string
# text: string
# vector: fixed_size_list<item: float>[768]
#   child 0, item: float

# %% [markdown]
# #### Augmented Generation
# > With the Context information that is fetched from the knowledge repo, the Original query is sent to LLM for provinding answer
# > It answers from within the context provided

# %% [markdown]
# **Query Mechanism**
# Pass the Original Query through the transformaton and expansion pipeline
# Then consolidate before being used for retrieval

# %%
# Query = "How various industries taking advantage of AI?"
Query = "Hybrid CLoud and Edge are same?"
# Query = "How new trends of AI challenging Cloud Security?"
# Query = "What is Private Cloud? Is it viable?"
# Query = "How big is the IoT industry in terms of business volume?"

Context = []

# First Make Semantic Search based on the Query
Query_Vector = Embedder_2.encode (Query).tolist ()
Results = table.search(Query_Vector).distance_type("cosine").distance_range(upper_bound=0.6).limit(5).to_list ()

# Append to the list
Text_List = [r['text'] for r in Results]
Context = Context + Text_List

# Identtify Keywords from the query
Keywords = query_keywords (Query)

# Keyword search done in the Vector DB
for word in Keywords :
    
    # Search is enabled by the Full Text Search Index in the DB
    Results = table.search(word).limit(5).to_list ()
    Text_List = [r['text'] for r in Results]
    Context = Context + Text_List

# Run a serch based on Query itself
Results = table.search(Query).limit(5).to_list ()
Text_List = [r['text'] for r in Results]
Context = Context + Text_List

# remove duplicates
Context = list(set(Context))
print (len(Context))
# Out:
# 21

# %%
Context

# %% [markdown]
# **Generation**
# With the context build based on both meaning and word search, re-ranking is necessary
# Once Re-ranked, take top_k and provide as context for generation

# %%
# Re-rank the picked chunks of text based on semantic similarity with the original Query
Re_Rank_Context = re_rank_text (Query, Context)
Re_Rank_Context = Re_Rank_Context [:10]

# Instruction for the LLM
Instruction = """You are given context information and a user query. You have to provide detailed answer to user query based on information provided in context.
                Provide an informative answer to the user query **BASED** on the context.
                If sufficient details are not in context, respond as "No Sufficient Details"
            """

response = Gen_Client.models.generate_content(
                model="gemini-2.5-flash-lite",
                config =types.GenerateContentConfig(
                            system_instruction=Instruction,
                            # temperature=0.0
                            ),
                contents = ["Context : \n"+str(Re_Rank_Context), "User Query : \n"+Query]
)

print(response.text)
# Out:
# No, Hybrid Cloud and Edge computing are not the same, although they can be integrated.
#
# *   **Hybrid Cloud** refers to a cloud computing environment that uses a combination of at least two different cloud providers, or a mix of private and public cloud infrastructure. Organizations often adopt hybrid cloud strategies to leverage specific technologies from different providers or to reduce the risk of relying on a single cloud service provider. It allows for workloads to be migrated between on-premises data centers, private cloud infrastructure, and public cloud infrastructure.
#
# *   **Edge Computing** involves running workloads closer to the devices and end-users, rather than in a centralized cloud provider's data center. This means processing data directly on connected edge devices. Cloud providers also offer edge computing services, enabling data processing, analysis, and storage near endpoints, outside of their main data centers.
#
# While distinct, there is an integration between them. Edge AI, for example, combines AI models and the Internet of Things (IoT) to perform tasks directly on interconnected edge devices. Furthermore, edge infrastructure services can be designed to integrate seamlessly with hybrid cloud strategies.

# %%
# Re-struture the output
Instruction = """You are given context information and a user query. You have to provide detailed answer ("Answer") to user query based on information provided in context.
                Provide an informative answer to the user query **BASED** on the context.
                If sufficient details are not in context, respond as "No Sufficient Details"
                Also you will have to provide a summary of the context in 500 words ("Context"), as a justification to your answer
                Respond text in JSON format with keys : {"Answer" : string, "Context" : Summary string}
            """

response = Gen_Client.models.generate_content(
                model="gemini-2.5-flash-lite",
                config =types.GenerateContentConfig(
                            system_instruction=Instruction,
                            # temperature=0.0
                            ),
                contents = ["Context : \n"+str(Re_Rank_Context), "User Query : \n"+Query]
)

print(response.text)
# Out:
# ```json
# {
#  "Answer": "No, Hybrid Cloud and Edge computing are not the same, although they are increasingly integrated. Hybrid cloud refers to a computing environment that combines two or more cloud providers, or a mix of private and public cloud infrastructure, to leverage specific technologies or mitigate risks. Edge computing, on the other hand, involves running workloads closer to the devices and end-users, rather than in a centralized cloud provider's data center. While cloud providers offer edge computing services, and edge AI combines AI models with the Internet of Things (IoT) to perform tasks on edge devices, they represent distinct concepts within modern IT infrastructures.",
#  "Context": "The provided context discusses hybrid cloud and edge computing, highlighting their distinct characteristics and growing integration. Hybrid cloud is defined as the use of two or more cloud providers or a combination of private and public cloud infrastructure. This approach is adopted to utilize specific technologies, software, or features offered by different providers, or to reduce the risk of relying on a single cloud service provider (CSP). Many enterprise organizations favor hybrid cloud models for their flexibility, scalability, and cost optimization benefits compared to traditional on-premises setups. A study by Fortune Business Insights indicates significant market growth for hybrid cloud, projecting it to reach USD 385 billion by 2025.\n\nEdge computing, in contrast, involves running workloads at the 'edge'—closer to the devices and end-users—instead of in a remote cloud data center. However, it's important to note that cloud providers also offer edge computing services. For example, AWS provides edge services that facilitate data processing, analysis, and storage near endpoints, allowing for the deployment of APIs and tools outside of AWS data centers.\n\nThe integration of edge computing and AI (often referred to as edge AI) is a significant growth driver, enabling tasks to be performed directly on connected edge devices. This combines AI models with the Internet of Things (IoT). Both hybrid cloud and edge computing share underlying technologies like containers and Kubernetes, which are crucial for edge deployments. Furthermore, cloud providers offer services that help design, deploy, and manage secure edge environments that integrate seamlessly with hybrid cloud and AI strategies, indicating a trend towards converged solutions. While hybrid cloud focuses on the distribution of workloads across different cloud environments, edge computing focuses on the physical location of workload execution, bringing it closer to the data source and users."
# }
# ```

# %% [markdown]
# **More details**
# Variation of response to include summary

# %%
# Generation with different LLM
Instruction = """You are given context information and a user query. You have to provide detailed answer to user query based on information provided in context.
                Provide an informative answer to the user query **BASED** on the context. Provide as Marked Down Text
                If sufficient details are not in context, respond as "No Sufficient Details"
            """

messages=[
            {
                "role": "system",
                "content": Instruction,
            },
            {
                "role": "user",
                "content": "Context : \n"+str(Re_Rank_Context)+"\n\nUser Query : \n"+Query,
            }
        ]
completion = Retrieval_Client.chat.completions.create(
    messages=messages,    
    model="llama-3.3-70b-versatile",
    # model="openai/gpt-oss-120b",
    stop=None,
)

print(completion.choices[0].message.content)
# Out:
# ### Hybrid Cloud and Edge: Understanding the Difference
# Hybrid cloud and edge computing are related but distinct concepts in the realm of cloud computing and distributed infrastructure.
#
# #### Hybrid Cloud
# Hybrid cloud refers to a cloud computing environment that combines two or more cloud providers, which can include public, private, and on-premises infrastructure. The purpose of a hybrid cloud setup is to leverage the specific strengths, technologies, software, or features offered by each provider, thereby enhancing flexibility, scalability, and cost optimization. According to various studies, the majority of enterprise organizations have adopted a hybrid cloud approach due to its numerous benefits.
#
# #### Edge Computing
# Edge computing, on the other hand, involves running workloads at the edge, which means closer to devices and end-users. This approach is crucial for reducing latency, improving real-time data processing, and enhancing the overall performance of applications and services. Edge computing can involve the integration of AI models (edge AI) to perform tasks directly on connected edge devices, facilitating real-time decision-making and more efficient data processing.
#
# #### Key Differences
# - **Location of Workloads**: Hybrid cloud is about distributing workloads across different cloud environments (public, private, on-premises), while edge computing focuses on running workloads at the edge, near the source of the data.
# - **Purpose**: The primary purpose of hybrid cloud is to achieve flexibility, scalability, and cost-effectiveness by utilizing multiple cloud environments. Edge computing aims to reduce latency, improve real-time processing, and facilitate data analysis closer to where data is generated.
# - **Infrastructure**: Hybrid cloud involves a combination of cloud providers and infrastructure types, whereas edge computing involves deploying infrastructure and services at the edge, often utilizing specialized edge devices and cloud services designed for edge computing.
#
# #### Conclusion
# While hybrid cloud and edge computing are distinct concepts, they can complement each other. Organizations can leverage a hybrid cloud strategy that includes edge computing services, allowing them to process data closer to the edge while still benefiting from the scalability and flexibility of cloud computing. In essence, hybrid cloud and edge are not the same but can be part of a comprehensive strategy to optimize data processing, application performance, and overall IT infrastructure.
